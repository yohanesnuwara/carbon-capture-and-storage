# %% [markdown]
# <a href="https://colab.research.google.com/github/yohanesnuwara/bsc-thesis-carbon-capture-storage/blob/master/main/pyfehm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PyFEHM as Geomechanical Simulator
#
# PyFEHM is developed by Los Alamos National Laboratory (LANL). PyFEHM may be useful for its application in CO<sub>2</sub> injection.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Install from PyFEHM github repo.

# %%
# !pip install git+https://github.com/lanl/PyFEHM
# Out:
# ...
#   Cloning https://github.com/lanl/PyFEHM to /tmp/pip-req-build-n2_4jB
#   Running command git clone -q https://github.com/lanl/PyFEHM /tmp/pip-req-build-n2_4jB
# ...
#   Created wheel for PyFEHM: filename=PyFEHM-1.0.4-cp27-none-any.whl size=176205 sha256=9d55080893ce092c10fa2c1fff2bcb1b1c43a3cb9333a37f48a32170bc256fcc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-Uy0IDA/wheels/69/dc/74/9050d76844840af626957651bc488e0a1bc476913acdf8bd7c
# Successfully built PyFEHM
# ...

# %%
import os,sys
sys.path.append('/content/PyFEHM')

# %%
from fdata import*
from fpost import*

dat = fdata()
root = 'tut1'

x=np.linspace(0,10,11)
dat.grid.make(root+'_GRID.inp',x=x,y=x,z=x)
dat.grid.plot(root+'_GRID.png',color='r',angle=[45,45])
